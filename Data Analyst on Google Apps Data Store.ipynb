# %% [markdown]
# <center> <h1 style="background-color:orange; color:white"><br>Google Play Store Apps Exploratory Data Analysis (EDA)<br></h1></center>

# %% [markdown]
# # `Problem Statement`
# 1. This project understands how the Google Play Store having high demand apps of various category. And look any relationship attributes between features.
# 2. Finally, find the meaning full insights from the datasets.

# %% [markdown]
# ## `Importing the necessary libraries`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings("ignore")
# allow matplotlib to plot inline with frontends like Jupyter

# %% [markdown]
# ## `Load the dataset into dataframe`

# %%
df = pd.read_csv(r'C:\Users\PRANAY\Documents\TwinLeran Data science Paid Intership\Internship works\Project 2\Google Apps data.csv')

# %%
# look at the first 5 records in the apps dataframe
df.head(5)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           5  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           6                              Sketch - Draw & Paint
# 4           7              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  Art And Design     4.1      159  19.0     10000  Free    0.0
# 1  Art And Design     3.9      967  14.0    500000  Free    0.0
# 2  Art And Design     4.7    87510   8.7   5000000  Free    0.0
# 3  Art And Design     4.5   215644  25.0  50000000  Free    0.0
# 4  Art And Design     4.3      967   2.8    100000  Free    0.0
#
#   Content Rating Last Updated         Current Ver Minimum Android Ver  \
# 0         Others     7-Jan-18               1.0.0               4.0.3
# 1         Others    15-Jan-18               2.0.0               4.0.3
# 2         Others     1-Aug-18               1.2.4               4.0.3
# 3           Teen     8-Jun-18  Varies with device                 4.2
# 4         Others    20-Jun-18                 1.1                 4.4
#
#          Genres
# 0  Art & Design
# 1  Art & Design
# 2  Art & Design
# 3  Art & Design
# 4  Art & Design

# %%
# look at the random 5 records in the apps dataframe
df.sample(5)
# Out:
#       Unnamed: 0                             App   Category  Rating  Reviews  \
# 7067        7660     Tamilnadu EB Online Payment    Finance     3.7      155
# 5094        5596                      FX LITE BO    Finance     3.6       73
# 6202        6761                     CXmodel-ufo     Family     3.8       19
# 7184        7780   Fashion Girls Dress up Makeup     Family     4.4      115
# 565          601  Elevate - Brain Training Games  Education     4.5   248912
#
#       Size  Installs  Type  Price Content Rating Last Updated  \
# 7067   3.9    100000  Free    0.0         Others    30-Jul-18
# 5094  14.0     10000  Free    0.0         Others    18-Oct-16
# 6202  12.0      1000  Free    0.0         Others    19-Jan-17
# 7184  31.0     10000  Free    0.0         Others    13-Jul-18
# 565    1.0   5000000  Free    0.0         Others    30-Jul-18
#
#              Current Ver Minimum Android Ver         Genres
# 7067               1.0.0               4.0.3        Finance
# 5094               1.5.0                 4.1        Finance
# 6202                 2.1                 2.2  Entertainment
# 7184                   1                   4     Simulation
# 565   Varies with device                  -1      Education

# %% [markdown]
# ## Description of App Dataset columns
# 1. App : The name of the app
# 2. Category : The category of the app
# 3. Rating : The rating of the app in the Play Store
# 4. Reviews : The number of reviews of the app
# 5. Size : The size of the app
# 6. Install : The number of installs of the app
# 7. Type : The type of the app (Free/Paid)
# 8. The price of the app (0 if it is Free)
# 9. Content Rating :The appropiate target audience of the app
# 10. Genres: The genre of the app
# 11. Last Updated : The date when the app was last updated
# 12. Current Ver : The current version of the app
# 13. Android Ver : The minimum Android version required to run the app

# %%
# type of Category
df['Category'].unique()
# Out:
# array(['Art And Design', 'Auto And Vehicles', 'Beauty',
#        'Books And Reference', 'Business', 'Comics', 'Communication',
#        'Dating', 'Education', 'Entertainment', 'Events', 'Finance',
#        'Food And Drink', 'Health And Fitness', 'House And Home',
#        'Libraries And Demo', 'Lifestyle', 'Game', 'Family', 'Medical',
#        'Social', 'Shopping', 'Photography', 'Sports', 'Travel And Local',
#        'Tools', 'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'Video Players', 'News And Magazines', 'Maps And Navigation'],
#       dtype=object)

# %%
# type of Type
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
# type of Content Rating
df['Content Rating'].unique()
# Out:
# array(['Others', 'Teen', nan], dtype=object)

# %%
# type of Genres
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Adventure', 'Arcade', 'Casual', 'Card', 'Action',
#        'Strategy', 'Puzzle', 'Sports', 'Music', 'Word', 'Racing',
#        'Simulation', 'Board', 'Trivia', 'Role Playing', 'Educational',
#        'Music & Audio', 'Video Players & Editors', 'Medical', 'Social',
#        'Shopping', 'Photography', 'Travel & Local', 'Tools',
#        'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'News & Magazines', 'Maps & Navigation', 'Casino'], dtype=object)

# %%
# look that the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8276 entries, 0 to 8275
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           8276 non-null   int64
#  1   App                  8276 non-null   object
#  2   Category             8276 non-null   object
#  3   Rating               8276 non-null   float64
#  4   Reviews              8276 non-null   int64
#  5   Size                 8276 non-null   float64
#  6   Installs             8276 non-null   int64
#  7   Type                 8276 non-null   object
#  8   Price                8276 non-null   float64
#  9   Content Rating       7915 non-null   object
#  10  Last Updated         8276 non-null   object
#  11  Current Ver          8276 non-null   object
#  12  Minimum Android Ver  8276 non-null   object
#  13  Genres               8276 non-null   object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 905.3+ KB

# %%
# Check statistics of data set
df.describe()
# Out:
#         Unnamed: 0       Rating       Reviews         Size      Installs  \
# count  8276.000000  8276.000000  8.276000e+03  8276.000000  8.276000e+03
# mean   4560.609957     4.175121  2.803270e+05    18.897761  9.658206e+06
# std    2560.879748     0.534762  2.096170e+06    22.376521  5.986505e+07
# min       0.000000     1.000000  1.000000e+00     0.008300  1.000000e+00
# 25%    2459.750000     4.000000  1.290000e+02     2.800000  1.000000e+04
# 50%    4613.500000     4.300000  3.213500e+03     9.500000  1.000000e+05
# 75%    6765.250000     4.500000  4.627800e+04    27.000000  1.000000e+06
# max    8916.000000     5.000000  7.815831e+07   100.000000  1.000000e+09
#
#              Price
# count  8276.000000
# mean      1.028758
# std      16.776622
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     400.000000

# %% [markdown]
# # Observations:
#
# 1. There are 8276 App in the data set.
#
# 2. There are 14 features in the data set.
#
# 3. There are missing values in the data set Content Rating is 361.
#
# 4. There are 2 interger, 8 object and 3 floats in dataset.

# %% [markdown]
# ## `Dropping Relevant columns`

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art And Design     4.1
# 1                                Coloring book moana  Art And Design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art And Design     4.7
# 3                              Sketch - Draw & Paint  Art And Design     4.5
# 4              Pixel Draw - Number Art Coloring Book  Art And Design     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating Last Updated  \
# 0      159  19.0     10000  Free    0.0         Others     7-Jan-18
# 1      967  14.0    500000  Free    0.0         Others    15-Jan-18
# 2    87510   8.7   5000000  Free    0.0         Others     1-Aug-18
# 3   215644  25.0  50000000  Free    0.0           Teen     8-Jun-18
# 4      967   2.8    100000  Free    0.0         Others    20-Jun-18
#
#           Current Ver Minimum Android Ver        Genres
# 0               1.0.0               4.0.3  Art & Design
# 1               2.0.0               4.0.3  Art & Design
# 2               1.2.4               4.0.3  Art & Design
# 3  Varies with device                 4.2  Art & Design
# 4                 1.1                 4.4  Art & Design

# %% [markdown]
# ### Some Data Cleaning

# %%
# look at the random 10 records in the apps dataframe to verify the cleaned columns
df.sample(10)
# Out:
#                                            App             Category  Rating  \
# 2555             Water Droplets Keyboard Theme      Personalization     4.1
# 2428                          AT&T Smart Wi-Fi                Tools     3.9
# 727      Tribeca Shortlist - Handpicked Movies        Entertainment     3.9
# 168   eBoox new: Reader for fb2 epub zip books  Books And Reference     4.9
# 566     NeuroNation - Focus and Brain Training            Education     4.5
# 2995              Magisto Video Editor & Maker        Video Players     4.3
# 7341                El Laberinto del Demonio 2               Family     4.1
# 6719  Dr. Parker : Real car parking simulation                 Game     4.6
# 5737          Postings (Craigslist Search App)             Shopping     4.3
# 5568                              CG Fit Scale   Health And Fitness     2.6
#
#       Reviews  Size  Installs  Type  Price Content Rating Last Updated  \
# 2555      398   6.8    100000  Free    0.0         Others    29-Jun-18
# 2428    18513   6.1  10000000  Free    0.0         Others    26-Apr-18
# 727       801  57.0    100000  Free    0.0           Teen    21-Mar-18
# 168      2739  21.0     50000  Free    0.0         Others    17-Jul-18
# 566    248555   1.0   5000000  Free    0.0         Others    23-May-18
# 2995   960726   1.0  10000000  Free    0.0         Others     2-Aug-18
# 7341     3654  25.0    100000  Free    0.0           Teen    14-Apr-17
# 6719    15829  95.0   1000000  Free    0.0         Others    24-Jul-18
# 5737   151095  12.0   5000000  Free    0.0            NaN     1-Jul-18
# 5568       13   3.3      1000  Free    0.0         Others    13-Oct-15
#
#              Current Ver Minimum Android Ver                   Genres
# 2555              6.6.28               4.0.3          Personalization
# 2428                 3.2                 4.1                    Tools
# 727              4.003.1                 4.3            Entertainment
# 168                    2                   3        Books & Reference
# 566   Varies with device               4.0.3                Education
# 2995  Varies with device                  -1  Video Players & Editors
# 7341               1.0.1                   4                   Puzzle
# 6719                1.29                   4                   Racing
# 5737              4.0.13                 4.1                 Shopping
# 5568               1.1.4                   4         Health & Fitness

# %%
print("Categories in 'App' variable:",end=" " )
print(df['App'].unique())

print('===================================')

print("Categories in 'Category' variable:",end=" ")
print(df['Category'].unique())

print('===================================')

print("Categories in'Type' variable:",end=" " )
print(df['Type'].unique())

print('===================================')

print("Categories in 'Content Rating' variable:",end=" " )
print(df['Content Rating'].unique())

print('===================================')

print("Categories in 'Last Updated' variable:",end=" " )
print(df['Last Updated'].unique())

print('===================================')

print("Categories in 'Current Ver' Variable:",end=" ")
print(df['Current Ver'].unique())

print('===================================')

print("Categories in 'Minimum Android Ver' Variable:",end=" ")
print(df['Minimum Android Ver'].unique())

print('===================================')

print("Categories in 'Genres' Variable:",end=" ")
print(df['Genres'].unique())
# Out:
# Categories in 'App' variable: ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Fr. Mike Schmitz Audio Teachings' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# ===================================
# Categories in 'Category' variable: ['Art And Design' 'Auto And Vehicles' 'Beauty' 'Books And Reference'
#  'Business' 'Comics' 'Communication' 'Dating' 'Education' 'Entertainment'
#  'Events' 'Finance' 'Food And Drink' 'Health And Fitness' 'House And Home'
#  'Libraries And Demo' 'Lifestyle' 'Game' 'Family' 'Medical' 'Social'
#  'Shopping' 'Photography' 'Sports' 'Travel And Local' 'Tools'
#  'Personalization' 'Productivity' 'Parenting' 'Weather' 'Video Players'
#  'News And Magazines' 'Maps And Navigation']
# ===================================
# Categories in'Type' variable: ['Free' 'Paid']
# ===================================
# Categories in 'Content Rating' variable: ['Others' 'Teen' nan]
# ===================================
# Categories in 'Last Updated' variable: ['7-Jan-18' '15-Jan-18' '1-Aug-18' ... '20-Jan-14' '16-Feb-14' '23-Mar-14']
# ===================================
# Categories in 'Current Ver' Variable: ['1.0.0' '2.0.0' '1.2.4' ... '1.5.447' '1.0.612928' '0.3.4']
# ===================================
# Categories in 'Minimum Android Ver' Variable: ['4.0.3' '4.2' '4.4' '2.3' '3' '4.1' '4' '2.3.3' '-1' '2.2' '5' '6' '1.6'
#  '1.5' '2.1' '7' '4.3' '2' '3.2' '5.1' '7.1' '8' '3.1' '2.0.1' '1']
# ===================================
# Categories in 'Genres' Variable: ['Art & Design' 'Auto & Vehicles' 'Beauty' 'Books & Reference' 'Business'
#  'Comics' 'Communication' 'Dating' 'Education' 'Entertainment' 'Events'
#  'Finance' 'Food & Drink' 'Health & Fitness' 'House & Home'
#  'Libraries & Demo' 'Lifestyle' 'Adventure' 'Arcade' 'Casual' 'Card'
#  'Action' 'Strategy' 'Puzzle' 'Sports' 'Music' 'Word' 'Racing'
#  'Simulation' 'Board' 'Trivia' 'Role Playing' 'Educational'
#  'Music & Audio' 'Video Players & Editors' 'Medical' 'Social' 'Shopping'
#  'Photography' 'Travel & Local' 'Tools' 'Personalization' 'Productivity'
#  'Parenting' 'Weather' 'News & Magazines' 'Maps & Navigation' 'Casino']

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 5 numerical features : ['Rating', 'Reviews', 'Size', 'Installs', 'Price']
#
# We have 8 categorical features : ['App', 'Category', 'Type', 'Content Rating', 'Last Updated', 'Current Ver', 'Minimum Android Ver', 'Genres']

# %% [markdown]
# ## `Dropping the null or missing values`

# %% [markdown]
# Missing values are usually represented in the form of Nan or null or None in the dataset.
#
# Finding whether we have null values in the data is by using the isnull() function.
#
# There are many values which are missing, in pandas dataframe these values are reffered to as np.nan. We want to deal with these values beause we can't use nan values to train models. Either we can remove them to apply some strategy to replace them with other values.
#
# To keep things simple we will be dropping nan values

# %%
# check on null values
df.isna().sum()
# Out:
# App                      0
# Category                 0
# Rating                   0
# Reviews                  0
# Size                     0
# Installs                 0
# Type                     0
# Price                    0
# Content Rating         361
# Last Updated             0
# Current Ver              0
# Minimum Android Ver      0
# Genres                   0
# dtype: int64

# %% [markdown]
# Here, we realized that there are 361 rows having null values under column 'Content Rating'.
# Hence, we decided to replace the null values with mode of overall 'Content Rating' values.

# %%
# lets fill nan values with the help of mode.
df['Content Rating'].fillna('Others',inplace=True)

# %%
# check on null values
df.isna().sum()
# Out:
# App                    0
# Category               0
# Rating                 0
# Reviews                0
# Size                   0
# Installs               0
# Type                   0
# Price                  0
# Content Rating         0
# Last Updated           0
# Current Ver            0
# Minimum Android Ver    0
# Genres                 0
# dtype: int64

# %% [markdown]
# ## `Drop the duplicate values in our datasets`

# %%
print("Before Dropping the duplicate values has Rows {}, Columns {}".format(*df.shape))
df.drop_duplicates(subset=['App'], inplace=True)
print("After dropping the duplicate values has Rows {}, Columns {}".format(*df.shape))
# Out:
# Before Dropping the duplicate values has Rows 8276, Columns 13
# After dropping the duplicate values has Rows 8190, Columns 13

# %% [markdown]
# ## `Grouping the data starting with App and Reviews`

# %%
df = df.groupby(['App', 'Reviews', 'Category', 'Rating', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 
                           'Last Updated', 'Current Ver', 'Minimum Android Ver'], as_index=False)
# reassign Installs values with their mean
df = df['Installs'].mean()
# sort the dataframe by Reviews descendingly
df.sort_values(by='Reviews', ascending=False, inplace=True)

# %%
# check on statistical information of the dataframe
df.describe()
# Out:
#             Reviews       Rating         Size        Price      Installs
# count  8.190000e+03  8190.000000  8190.000000  8190.000000  8.190000e+03
# mean   2.554354e+05     4.173321    18.802963     1.038342  9.171613e+06
# std    1.986309e+06     0.536691    22.265248    16.864040  5.827170e+07
# min    1.000000e+00     1.000000     0.008300     0.000000  1.000000e+00
# 25%    1.260000e+02     4.000000     2.800000     0.000000  1.000000e+04
# 50%    3.009500e+03     4.300000     9.400000     0.000000  1.000000e+05
# 75%    4.391425e+04     4.500000    27.000000     0.000000  1.000000e+06
# max    7.815831e+07     5.000000   100.000000   400.000000  1.000000e+09

# %% [markdown]
# <center> <h1 style="background-color:orange; color:white"><br>Exploratory Analysis and Visualization<br></h1></center>

# %% [markdown]
# ## Visualize average score distribution to make some conclusion.
# 1. Histogram
# 2. Kernel Distribution Function (KDE)

# %% [markdown]
# ## Histogram & KDE

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='Category',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='Category',kde=True,hue='Type')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='Genres',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='Genres',kde=True,hue='Type')
plt.show()

# %% [markdown]
# ## Insights
# from the above plot it show that people are more using free apps of various category

# %%
# get the number of apps for each category
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Category', data=df)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From this plotting we know that most of the apps in the play store are from the categories of 'Family', 'Game' and also 'Tools.

# %%
# get the number of installs for each category
categories = df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df = category_installs_sum_df.reset_index()  # to convert groupby object into dataframe

plt.figure(figsize=(10, 5))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.ylabel('Installs (e+10)')
plt.title('Number of Installs For Each Category')
plt.show()

# %% [markdown]
# From this distribution plotting of number of installs for each category, we can see that most of the apps being downloaded and installed are from the categories of 'Game' and 'Communication'.

# %% [markdown]
# ### Rating

# %%
# show the distribution of rating
plt.figure(figsize=(10, 5))
sns.countplot(x='Rating', data=df)
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.

# %%
# plot the graphs of reviews, size, installs and price per rating
rating_df = df.groupby('Rating').sum().reset_index()

fig, axes = plt.subplots(1, 4, figsize=(14, 4))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')

axes[1].plot(rating_df['Rating'], rating_df['Size'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Size')
axes[1].set_title('Size Per Rating')

axes[2].plot(rating_df['Rating'], rating_df['Installs'], 'g')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')
axes[2].set_title('Installs Per Rating')

axes[3].plot(rating_df['Rating'], rating_df['Price'], 'k')
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')
axes[3].set_title('Price Per Rating')

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# From the above plottings, we can imply that most of the apps with higher rating range of 4.0 - 4.7 are having high amount of reviews, size, and installs. In terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high rating.

# %% [markdown]
# ### Application Type

# %%
# application type distribution
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Type', data=df)
plt.title('Type Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From the plot we can imply that majority of the apps in the Play Store are Free apps.

# %%
# show the distribution of apps in term of their rating, size and type
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df['Size'],
               y=df['Rating'],
               hue=df['Type'],
               s=50,data=df)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rating'>

# %% [markdown]
# From this scatter plot, we can imply that majority of the free apps are small in size and having high rating. While for paid apps, we have quite equal distribution in term on size and rating.

# %%
# correlation
df.corr()
# Out:
#            Reviews    Rating      Size     Price  Installs
# Reviews   1.000000  0.055076  0.036964 -0.007791  0.624050
# Rating    0.055076  1.000000  0.038632 -0.021215  0.040131
# Size      0.036964  0.038632  1.000000 -0.017876 -0.010792
# Price    -0.007791 -0.021215 -0.017876  1.000000 -0.009656
# Installs  0.624050  0.040131 -0.010792 -0.009656  1.000000

# %%
fig, axes = plt.subplots(figsize=(8, 8))
sns.heatmap(df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %%
# 1. What is the top 5 apps on the basis of installs?
df = df.sort_values(by=['Installs'], ascending=False)
df.head(5)
# Out:
#                           App   Reviews             Category  Rating  Size  \
# 3431                 Facebook  78158306               Social     4.1   1.0
# 4007        Google Play Books   1433233  Books And Reference     3.9   1.0
# 4009  Google Play Movies & TV    906384        Video Players     3.7   1.0
# 4161                 Hangouts   3419249        Communication     4.0   1.0
# 4002              Google News    877635   News And Magazines     3.9  13.0
#
#       Type  Price Content Rating                   Genres Last Updated  \
# 3431  Free    0.0           Teen                   Social     3-Aug-18
# 4007  Free    0.0           Teen        Books & Reference     3-Aug-18
# 4009  Free    0.0           Teen  Video Players & Editors     6-Aug-18
# 4161  Free    0.0         Others            Communication    21-Jul-18
# 4002  Free    0.0           Teen         News & Magazines     1-Aug-18
#
#              Current Ver Minimum Android Ver      Installs
# 3431  Varies with device                  -1  1.000000e+09
# 4007  Varies with device                  -1  1.000000e+09
# 4009  Varies with device                  -1  1.000000e+09
# 4161  Varies with device                  -1  1.000000e+09
# 4002               5.2.0                 4.4  1.000000e+09

# %%
# 2. What is the top 5 reviewed apps?
df = df.sort_values(by=['Reviews'], ascending=False)
df.head(5)
# Out:
#                                            App   Reviews       Category  \
# 3431                                  Facebook  78158306         Social
# 7660                        WhatsApp Messenger  69119316  Communication
# 4421                                 Instagram  66577313         Social
# 5093  Messenger – Text and Video Chat for Free  56642847  Communication
# 2073                            Clash of Clans  44891723           Game
#
#       Rating  Size  Type  Price Content Rating         Genres Last Updated  \
# 3431     4.1   1.0  Free    0.0           Teen         Social     3-Aug-18
# 7660     4.4   1.0  Free    0.0         Others  Communication     3-Aug-18
# 4421     4.5   1.0  Free    0.0           Teen         Social    31-Jul-18
# 5093     4.0   1.0  Free    0.0         Others  Communication     1-Aug-18
# 2073     4.6  98.0  Free    0.0         Others       Strategy    15-Jul-18
#
#              Current Ver Minimum Android Ver      Installs
# 3431  Varies with device                  -1  1.000000e+09
# 7660  Varies with device                  -1  1.000000e+09
# 4421  Varies with device                  -1  1.000000e+09
# 5093  Varies with device                  -1  1.000000e+09
# 2073           10.322.16                 4.1  1.000000e+08

# %%
# 3. What is the top 5 expensive apps?
df = df.sort_values(by=['Price'], ascending=False)
df.head(5)
# Out:
#                                  App  Reviews   Category  Rating  Size  Type  \
# 4357        I'm Rich - Trump Edition      275  Lifestyle     3.6   7.3  Paid
# 4353  I am rich (Most expensive app)      129    Finance     4.1   2.7  Paid
# 4346                       I am Rich      180    Finance     4.3   3.8  Paid
# 8186                      💎 I'm rich      718  Lifestyle     3.8  26.0  Paid
# 4350                      I am Rich!       93    Finance     3.8  22.0  Paid
#
#        Price Content Rating     Genres Last Updated Current Ver  \
# 4357  400.00         Others  Lifestyle     3-May-18       1.0.1
# 4353  399.99           Teen    Finance     6-Dec-17           2
# 4346  399.99         Others    Finance    22-Mar-18           1
# 8186  399.99         Others  Lifestyle    11-Mar-18       1.0.0
# 4350  399.99         Others    Finance    11-Dec-17           1
#
#      Minimum Android Ver  Installs
# 4357                 4.1   10000.0
# 4353               4.0.3    1000.0
# 4346                 4.2    5000.0
# 8186                 4.4   10000.0
# 4350                 4.1    1000.0

# %%
# 4. What is the top 3 most installed apps in Game category?
df = df[df['Category'] == 'Game']
df = df.sort_values(by=['Installs'], ascending=False)
df.head(3)
# Out:
#                  App   Reviews Category  Rating  Size  Type  Price  \
# 6803  Subway Surfers  27722264     Game     4.5  76.0  Free    0.0
# 5947             Pou  10485308     Game     4.3  24.0  Free    0.0
# 7015    Temple Run 2   8118609     Game     4.3  62.0  Free    0.0
#
#      Content Rating  Genres Last Updated Current Ver Minimum Android Ver  \
# 6803         Others  Arcade    12-Jul-18      1.90.0                 4.1
# 5947         Others  Casual    25-May-18      1.4.77                   4
# 7015         Others  Action     5-Jul-18      1.49.1                   4
#
#           Installs
# 6803  1.000000e+09
# 5947  5.000000e+08
# 7015  5.000000e+08

# %%
# 5. Which 5 apps from Rating
df = df.sort_values(by=['Rating'], ascending=False)
df.head(5)
# Out:
#                        App  Reviews Category  Rating  Size  Type  Price  \
# 5258               Mu.F.O.        2     Game     5.0  16.0  Paid   0.99
# 6119              Ra Ga Ba        2     Game     5.0  20.0  Paid   1.49
# 1435      Brick Breaker BR        7     Game     5.0  19.0  Free   0.00
# 2891              EC Mover        5     Game     5.0   4.6  Free   0.00
# 7275  Trovami se ci riesci       11     Game     5.0   6.1  Free   0.00
#
#      Content Rating  Genres Last Updated Current Ver Minimum Android Ver  \
# 5258         Others  Arcade     3-Mar-17           1                 2.3
# 6119         Others  Arcade     8-Feb-17       1.0.4                 2.3
# 1435         Others  Arcade    23-Jul-18           1                 4.1
# 2891         Others  Racing     1-Aug-18        1.11               4.0.3
# 7275         Others  Arcade    11-Mar-17         0.1                 2.3
#
#       Installs
# 5258       1.0
# 6119       1.0
# 1435       5.0
# 2891      10.0
# 7275      10.0

# %% [markdown]
# ## `Observation`

# %% [markdown]
# The Google Play Store Apps report provides some useful insights regarding the trending of the apps in the play store. As per the graphs visualizations shown above, most of the trending apps (in terms of users' installs) are from the categories like GAME, COMMUNICATION, and TOOL even though the amount of available apps from these categories are twice as much lesser than the category FAMILY. The trending of these apps are most probably due to their nature of being able to entertain or assist the user. Besides, it also shows a good trend where we can see that developers from these categories are focusing on the quality instead of the quantity of the apps.
#
# Other than that, the charts shown above actually implies that most of the apps having good ratings of above 4.0 are mostly confirmed to have high amount of reviews and user installs. There are some spikes in term of size and price but it shouldn't reflect that apps with high rating are mostly big in size and pricy as by looking at the graphs they are most probably are due to some minority. Futhermore, most of the apps that are having high amount of reviews are from the categories of SOCIAL, COMMUNICATION and GAME like Facebook, WhatsApp Messenger, Instagram, Messenger – Text and Video Chat for Free, Clash of Clans etc.
